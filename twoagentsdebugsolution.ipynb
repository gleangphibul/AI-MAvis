# %%
# Import necessary modules from your files
import os
import subprocess
import numpy as np

from tqdm.notebook import tqdm

from searchclient.agent_types.classic import * 

# Import all action classes (used for hardcoding solutions) and actions libraries
from searchclient.domains.hospital.actions import (
    NoOpAction, MoveAction, PushAction, PullAction, AnyAction, DEFAULT_MAPF_ACTION_LIBRARY, DEFAULT_HOSPITAL_ACTION_LIBRARY
)

# Import state, goal description and level classes for the MAvis hospital environment
from searchclient.domains.hospital.state import HospitalState
from searchclient.domains.hospital.goal_description import HospitalGoalDescription
from searchclient.domains.hospital.level import HospitalLevel

# Import the Graph-Search algorithm
from searchclient.search_algorithms.graph_search import graph_search

# Import the different search strategies for both uninformed and informed search
from searchclient.strategies.bfs import FrontierBFS
from searchclient.strategies.dfs import FrontierDFS
from searchclient.strategies.bestfirst import FrontierBestFirst, FrontierGreedy, FrontierAStar

# Import heuristic classes, to be used in informed search methods
from searchclient.domains.hospital.heuristics import (
    HospitalZeroHeuristic, HospitalGoalCountHeuristics, HospitalAdvancedHeuristics
)

# Ensure the environment is set up properly
print("Modules imported successfully.")
# Out:
# Modules imported successfully.

# %%
# Function to load a level file
def load_level_file_from_path(path):
    with open(path, "r") as f:
        lines = f.readlines()
        lines = list(map(lambda line: line.strip(), lines))
        return lines
  
# Example usage: load_level('path_to_level_file.lvl')
level_path = "levels/TwoAgentsDebug.lvl"
level_lines = load_level_file_from_path(level_path)
level = HospitalLevel.parse_level_lines(level_lines)

# We can access the initial state of the level using the following code
initial_state = HospitalState(level, level.initial_agent_positions, level.initial_box_positions)

# We can access the goal description of the level using the following code
goal_description = HospitalGoalDescription(level, level.box_goals + level.agent_goals)

print('The initial state of the level is:')
print(initial_state)

print('\nThe goal description of the level is:')
print(goal_description) # which tells us where the level objects (like boxes and agents) should be placed to satisfy the goal
print('\nSo agent zero starts at {} and satisfies the goal at {}'.format(level.initial_agent_positions[0][0], goal_description.agent_goals[0][0]))
# Out:
# The initial state of the level is:
# ++++++++
# +    2 +
# +      +
# + 0    +
# +      +
# + 1    +
# +      +
# ++++++++
#
# The goal description of the level is:
# ((5, 5), '0', True) and ((6, 3), '1', True)
#
# So agent zero starts at (3, 2) and satisfies the goal at (5, 5)

# %%
from PIL import Image
from renderState import *

# Render some state of the level (here the initial state)
render_state(level_path=level_path, state=initial_state, output_path='twoagent')

# So the state looks like this in .txt format (what the computer uses):
print(initial_state)

# And the initial state looks like this in .png:
# You can either show the image in the notebook or open it in a new window
img = Image.open('twoagent.png')
img.show()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# State rendered and saved to twoagent.png
# ++++++++
# +    2 +
# +      +
# + 0    +
# +      +
# + 1    +
# +      +
# ++++++++

# %%
def render_plan(level_path, plan, strategy_name, heuristic_name, num_generated, elapsed_time, sol_length):

    str_plan = convert_plan_to_string(plan) #convert the plan to a string

    # this just makes sure that the meta information is displayed correctly in the visualization
    if strategy_name == 'greedy' or strategy_name == 'astar':
        strategy_name_pygame = strategy_name + ' w. ' + heuristic_name
    else:
        strategy_name_pygame = strategy_name
    
    subprocess.run(["python3", 
                    "renderMAvis.py", 
                    "--level", level_path, 
                    "--plan", str_plan, 
                    "--search_strategy", strategy_name_pygame, 
                    "--num_generated", str(num_generated), 
                    "--time_elapsed", str(elapsed_time), 
                    "--sol_length", str(sol_length)])

# %%
# Here is an example of a plan. A plan is a list of list of actions, where an action is an instance from searchclient.domains.hospital.actions
# The first axis of the list corresponds to a timestep in the plan. 
# Each element of the innermost list corresponds to an action of a different agent. 
# Check the documentation of graph_seach.py for more information!
hardcoded_plan = [[MoveAction("E")], [NoOpAction()], [MoveAction("W")]]

# Hardcode your solution here!
hardcoded_plan = [[MoveAction("E"), MoveAction("E"), NoOpAction()], [MoveAction("E"), MoveAction("S"), NoOpAction()], 
                  [MoveAction("E"), NoOpAction(), NoOpAction()], [MoveAction("S"), NoOpAction(), NoOpAction()], 
                  [MoveAction("S"), NoOpAction(), NoOpAction()]]

render_plan(level_path, hardcoded_plan, "Hardcoded sol", None, len(hardcoded_plan), "0.0", len(hardcoded_plan))
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Finished executing the plan

# %%
# Before running the search algorithm, we need to define the action set and the action library
# Use this library for pure pathfinding problems
action_library = DEFAULT_MAPF_ACTION_LIBRARY

# Use this library for sokoban-like problems (includes Push and Pull actions)
#action_library = DEFAULT_HOSPITAL_ACTION_LIBRARY

# Every agent will have the same action set
action_set = [action_library] * level.num_agents

# In order to run Graph-Search, we need to specify the initial state, action set, goal description, and frontier 

# If needed, we need to specify and fetch a heuristic function before initializing the frontier (informed search) 
# When adding new heuristics, remember to update the dictionary! 
# Use a string that matches the name of the heuristic function in the heuristics.py file
heuristic_name = "zero" 
heuristic = {
        'zero': HospitalZeroHeuristic,
        'goalcount': HospitalGoalCountHeuristics,
        'advanced': HospitalAdvancedHeuristics,
    }.get(heuristic_name, HospitalZeroHeuristic)() # make sure you understand what .get() does


# Finally, let's pick the search strategy and fetch the relevant frontier
strategy_name = "dfs" 
frontier = {
        'bfs': FrontierBFS,
        'dfs': FrontierDFS,
        'astar': lambda: FrontierAStar(heuristic),
        'greedy': lambda: FrontierGreedy(heuristic)
    }.get(strategy_name, FrontierBFS)() # make sure you understand what .get() does

# %%
# Now that we have defined the initial state, action set, goal description, and frontier, we can run the search algorithm
planning_success, plan, num_generated, elapsed_time = graph_search(initial_state, action_set, goal_description, frontier)

# The graph search function returns the following:
print('Planning successful:', planning_success)
print('Plan:', plan)
print('Solution length:', len(plan))
print('Number of states generated:', num_generated)
print('Elapsed time:', elapsed_time)
# Out:
# this is the frontier <searchclient.strategies.dfs.FrontierDFS object at 0x1138d75c0>
# #Expanded:        0, #Frontier:        1, #Generated:        1, Time: 0,000 s, Memory: 79,05 MB
#
#
# #Expanded:        1, #Frontier:       95, #Generated:       96, Time: 0,002 s, Memory: 79,48 MB
#
#
# #Expanded:        2, #Frontier:      146, #Generated:      148, Time: 0,002 s, Memory: 79,48 MB
#
#
# #Expanded:        3, #Frontier:      199, #Generated:      202, Time: 0,003 s, Memory: 79,48 MB
#
#
# #Expanded:        4, #Frontier:      257, #Generated:      261, Time: 0,004 s, Memory: 79,53 MB
#
#
# #Expanded:        5, #Frontier:      275, #Generated:      280, Time: 0,005 s, Memory: 79,53 MB
#
#
# #Expanded:        6, #Frontier:      315, #Generated:      321, Time: 0,005 s, Memory: 79,53 MB
#
#
# #Expanded:        7, #Frontier:      350, #Generated:      357, Time: 0,006 s, Memory: 79,53 MB
#
#
# #Expanded:        8, #Frontier:      391, #Generated:      399, Time: 0,006 s, Memory: 79,53 MB
#
#
# #Expanded:        9, #Frontier:      422, #Generated:      431, Time: 0,007 s, Memory: 79,53 MB
#
#
# #Expanded:       10, #Frontier:      461, #Generated:      471, Time: 0,008 s, Memory: 79,55 MB
#
#
# #Expanded:       11, #Frontier:      492, #Generated:      503, Time: 0,008 s, Memory: 79,55 MB
#
#
# #Expanded:       12, #Frontier:      560, #Generated:      572, Time: 0,009 s, Memory: 79,55 MB
#
#
# #Expanded:       13, #Frontier:      605, #Generated:      618, Time: 0,010 s, Memory: 79,55 MB
#
#
# #Expanded:       14, #Frontier:      673, #Generated:      687, Time: 0,010 s, Memory: 79,55 MB
#
#
# #Expanded:       15, #Frontier:      708, #Generated:      723, Time: 0,012 s, Memory: 79,55 MB
#
#
# #Expanded:       16, #Frontier:      720, #Generated:      736, Time: 0,012 s, Memory: 79,55 MB
#
#
# #Expanded:       17, #Frontier:      732, #Generated:      749, Time: 0,012 s, Memory: 79,55 MB
#
#
# #Expanded:       18, #Frontier:      764, #Generated:      782, Time: 0,013 s, Memory: 79,55 MB
#
#
# #Expanded:       19, #Frontier:      775, #Generated:      794, Time: 0,013 s, Memory: 79,55 MB
#
#
# #Expanded:       20, #Frontier:      803, #Generated:      823, Time: 0,013 s, Memory: 79,55 MB
#
#
# #Expanded:       21, #Frontier:      872, #Generated:      893, Time: 0,014 s, Memory: 79,55 MB
#
#
# #Expanded:       22, #Frontier:      953, #Generated:      975, Time: 0,015 s, Memory: 79,55 MB
#
#
# #Expanded:       23, #Frontier:    1.063, #Generated:    1.086, Time: 0,016 s, Memory: 79,55 MB
#
#
# #Expanded:       24, #Frontier:    1.165, #Generated:    1.189, Time: 0,016 s, Memory: 79,56 MB
#
#
# #Expanded:       25, #Frontier:    1.219, #Generated:    1.244, Time: 0,017 s, Memory: 79,73 MB
#
#
# #Expanded:       26, #Frontier:    1.274, #Generated:    1.300, Time: 0,018 s, Memory: 79,73 MB
#
#
# #Expanded:       27, #Frontier:    1.354, #Generated:    1.381, Time: 0,019 s, Memory: 79,73 MB
#
#
# #Expanded:       28, #Frontier:    1.398, #Generated:    1.426, Time: 0,019 s, Memory: 79,75 MB
#
#
# #Expanded:       29, #Frontier:    1.441, #Generated:    1.470, Time: 0,020 s, Memory: 79,75 MB
#
#
# #Expanded:       30, #Frontier:    1.494, #Generated:    1.524, Time: 0,020 s, Memory: 79,75 MB
#
#
# #Expanded:       31, #Frontier:    1.509, #Generated:    1.540, Time: 0,020 s, Memory: 79,75 MB
#
#
# #Expanded:       32, #Frontier:    1.559, #Generated:    1.591, Time: 0,021 s, Memory: 79,75 MB
#
#
# #Expanded:       33, #Frontier:    1.603, #Generated:    1.636, Time: 0,021 s, Memory: 79,75 MB
#
#
# #Expanded:       34, #Frontier:    1.647, #Generated:    1.681, Time: 0,022 s, Memory: 79,75 MB
#
#
# #Expanded:       35, #Frontier:    1.718, #Generated:    1.753, Time: 0,022 s, Memory: 79,75 MB
#
#
# #Expanded:       36, #Frontier:    1.747, #Generated:    1.783, Time: 0,023 s, Memory: 79,75 MB
#
#
# #Expanded:       37, #Frontier:    1.776, #Generated:    1.813, Time: 0,024 s, Memory: 79,75 MB
#
#
# #Expanded:       38, #Frontier:    1.842, #Generated:    1.880, Time: 0,024 s, Memory: 79,77 MB
#
#
# #Expanded:       39, #Frontier:    1.896, #Generated:    1.935, Time: 0,051 s, Memory: 113,59 MB
#
#
# #Expanded:       40, #Frontier:    1.931, #Generated:    1.971, Time: 0,052 s, Memory: 113,59 MB
#
#
# #Expanded:       41, #Frontier:    2.002, #Generated:    2.043, Time: 0,052 s, Memory: 113,59 MB
#
#
# #Expanded:       42, #Frontier:    2.071, #Generated:    2.113, Time: 0,053 s, Memory: 113,59 MB
#
#
# #Expanded:       43, #Frontier:    2.090, #Generated:    2.133, Time: 0,053 s, Memory: 113,59 MB
#
#
# #Expanded:       44, #Frontier:    2.138, #Generated:    2.182, Time: 0,053 s, Memory: 113,59 MB
#
#
# #Expanded:       45, #Frontier:    2.172, #Generated:    2.217, Time: 0,053 s, Memory: 113,59 MB
#
#
# #Expanded:       46, #Frontier:    2.211, #Generated:    2.257, Time: 0,054 s, Memory: 113,59 MB
#
#
# #Expanded:       47, #Frontier:    2.269, #Generated:    2.316, Time: 0,054 s, Memory: 113,59 MB
#
#
# #Expanded:       48, #Frontier:    2.283, #Generated:    2.331, Time: 0,054 s, Memory: 113,59 MB
#
#
# #Expanded:       49, #Frontier:    2.320, #Generated:    2.369, Time: 0,055 s, Memory: 113,59 MB
#
#
# #Expanded:       50, #Frontier:    2.379, #Generated:    2.429, Time: 0,055 s, Memory: 113,59 MB
#
#
# #Expanded:       51, #Frontier:    2.449, #Generated:    2.500, Time: 0,055 s, Memory: 113,59 MB
#
#
# #Expanded:       52, #Frontier:    2.496, #Generated:    2.548, Time: 0,056 s, Memory: 113,59 MB
#
#
# #Expanded:       53, #Frontier:    2.550, #Generated:    2.603, Time: 0,056 s, Memory: 113,59 MB
#
#
# #Expanded:       54, #Frontier:    2.618, #Generated:    2.672, Time: 0,056 s, Memory: 113,59 MB
#
#
# #Expanded:       55, #Frontier:    2.660, #Generated:    2.715, Time: 0,057 s, Memory: 113,59 MB
#
#
# #Expanded:       56, #Frontier:    2.707, #Generated:    2.763, Time: 0,057 s, Memory: 113,59 MB
#
#
# #Expanded:       57, #Frontier:    2.764, #Generated:    2.821, Time: 0,057 s, Memory: 113,59 MB
#
#
# #Expanded:       58, #Frontier:    2.846, #Generated:    2.904, Time: 0,058 s, Memory: 113,59 MB
#
#
# #Expanded:       59, #Frontier:    2.906, #Generated:    2.965, Time: 0,058 s, Memory: 113,59 MB
#
#
# #Expanded:       60, #Frontier:    2.983, #Generated:    3.043, Time: 0,059 s, Memory: 113,59 MB
#
#
# #Expanded:       61, #Frontier:    3.055, #Generated:    3.116, Time: 0,059 s, Memory: 113,59 MB
#
#
# #Expanded:       62, #Frontier:    3.113, #Generated:    3.175, Time: 0,060 s, Memory: 113,59 MB
#
#
# #Expanded:       63, #Frontier:    3.164, #Generated:    3.227, Time: 0,060 s, Memory: 113,59 MB
#
#
# #Expanded:       64, #Frontier:    3.171, #Generated:    3.235, Time: 0,060 s, Memory: 113,59 MB
#
#
# #Expanded:       65, #Frontier:    3.225, #Generated:    3.290, Time: 0,060 s, Memory: 113,59 MB
#
#
# #Expanded:       66, #Frontier:    3.280, #Generated:    3.346, Time: 0,061 s, Memory: 113,59 MB
#
#
# #Expanded:       67, #Frontier:    3.307, #Generated:    3.374, Time: 0,061 s, Memory: 113,59 MB
#
#
# #Expanded:       68, #Frontier:    3.364, #Generated:    3.432, Time: 0,061 s, Memory: 113,59 MB
#
#
# #Expanded:       69, #Frontier:    3.403, #Generated:    3.472, Time: 0,061 s, Memory: 113,59 MB
#
#
# #Expanded:       70, #Frontier:    3.460, #Generated:    3.530, Time: 0,062 s, Memory: 113,59 MB
#
#
# #Expanded:       71, #Frontier:    3.504, #Generated:    3.575, Time: 0,062 s, Memory: 113,59 MB
#
#
# #Expanded:       72, #Frontier:    3.584, #Generated:    3.656, Time: 0,063 s, Memory: 113,59 MB
#
#
# #Expanded:       73, #Frontier:    3.662, #Generated:    3.735, Time: 0,063 s, Memory: 113,59 MB
#
#
# #Expanded:       74, #Frontier:    3.704, #Generated:    3.778, Time: 0,063 s, Memory: 113,59 MB
#
#
# #Expanded:       75, #Frontier:    3.747, #Generated:    3.822, Time: 0,064 s, Memory: 113,59 MB
#
#
# #Expanded:       76, #Frontier:    3.776, #Generated:    3.852, Time: 0,064 s, Memory: 113,59 MB
#
#
# #Expanded:       77, #Frontier:    3.823, #Generated:    3.900, Time: 0,064 s, Memory: 113,59 MB
#
#
# #Expanded:       78, #Frontier:    3.852, #Generated:    3.930, Time: 0,065 s, Memory: 113,59 MB
#
#
# #Expanded:       79, #Frontier:    3.889, #Generated:    3.968, Time: 0,065 s, Memory: 113,59 MB
#
#
# #Expanded:       80, #Frontier:    3.933, #Generated:    4.013, Time: 0,065 s, Memory: 113,59 MB
#
#
# #Expanded:       81, #Frontier:    3.983, #Generated:    4.064, Time: 0,066 s, Memory: 113,59 MB
#
#
# #Expanded:       82, #Frontier:    4.028, #Generated:    4.110, Time: 0,066 s, Memory: 113,59 MB
#
#
# #Expanded:       83, #Frontier:    4.083, #Generated:    4.166, Time: 0,066 s, Memory: 113,59 MB
#
#
# #Expanded:       84, #Frontier:    4.130, #Generated:    4.214, Time: 0,066 s, Memory: 113,59 MB
#
#
# #Expanded:       85, #Frontier:    4.171, #Generated:    4.256, Time: 0,067 s, Memory: 113,59 MB
#
#
# #Expanded:       86, #Frontier:    4.223, #Generated:    4.309, Time: 0,067 s, Memory: 113,59 MB
#
#
# #Expanded:       87, #Frontier:    4.313, #Generated:    4.400, Time: 0,068 s, Memory: 113,59 MB
#
#
# #Expanded:       88, #Frontier:    4.358, #Generated:    4.446, Time: 0,068 s, Memory: 113,59 MB
#
#
# #Expanded:       89, #Frontier:    4.390, #Generated:    4.479, Time: 0,068 s, Memory: 113,59 MB
#
#
# #Expanded:       90, #Frontier:    4.415, #Generated:    4.505, Time: 0,068 s, Memory: 113,59 MB
#
#
# #Expanded:       91, #Frontier:    4.465, #Generated:    4.556, Time: 0,069 s, Memory: 113,59 MB
#
#
# #Expanded:       92, #Frontier:    4.517, #Generated:    4.609, Time: 0,069 s, Memory: 113,59 MB
#
#
# #Expanded:       93, #Frontier:    4.562, #Generated:    4.655, Time: 0,069 s, Memory: 113,59 MB
#
#
# #Expanded:       94, #Frontier:    4.572, #Generated:    4.666, Time: 0,070 s, Memory: 113,59 MB
#
#
# #Expanded:       95, #Frontier:    4.577, #Generated:    4.672, Time: 0,070 s, Memory: 113,59 MB
#
#
# #Expanded:       96, #Frontier:    4.613, #Generated:    4.709, Time: 0,070 s, Memory: 113,59 MB
#
#
# #Expanded:       97, #Frontier:    4.637, #Generated:    4.734, Time: 0,070 s, Memory: 113,59 MB
#
#
# #Expanded:       98, #Frontier:    4.700, #Generated:    4.798, Time: 0,071 s, Memory: 113,59 MB
#
#
# #Expanded:       99, #Frontier:    4.747, #Generated:    4.846, Time: 0,071 s, Memory: 113,59 MB
#
#
# #Expanded:      100, #Frontier:    4.813, #Generated:    4.913, Time: 0,071 s, Memory: 113,59 MB
#
#
# #Expanded:      101, #Frontier:    4.837, #Generated:    4.938, Time: 0,072 s, Memory: 113,59 MB
#
#
# #Expanded:      102, #Frontier:    4.875, #Generated:    4.977, Time: 0,072 s, Memory: 114,09 MB
#
#
# #Expanded:      103, #Frontier:    4.886, #Generated:    4.989, Time: 0,072 s, Memory: 114,09 MB
#
#
# #Expanded:      104, #Frontier:    4.958, #Generated:    5.062, Time: 0,073 s, Memory: 114,09 MB
#
#
# #Expanded:      105, #Frontier:    5.025, #Generated:    5.130, Time: 0,073 s, Memory: 114,09 MB
#
#
# #Expanded:      106, #Frontier:    5.088, #Generated:    5.194, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      107, #Frontier:    5.117, #Generated:    5.224, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      108, #Frontier:    5.132, #Generated:    5.240, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      109, #Frontier:    5.144, #Generated:    5.253, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      110, #Frontier:    5.148, #Generated:    5.258, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      111, #Frontier:    5.168, #Generated:    5.279, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      112, #Frontier:    5.175, #Generated:    5.287, Time: 0,074 s, Memory: 114,09 MB
#
#
# #Expanded:      113, #Frontier:    5.207, #Generated:    5.320, Time: 0,075 s, Memory: 114,09 MB
#
#
# #Expanded:      114, #Frontier:    5.238, #Generated:    5.352, Time: 0,075 s, Memory: 114,09 MB
#
#
# #Expanded:      115, #Frontier:    5.253, #Generated:    5.368, Time: 0,075 s, Memory: 114,09 MB
#
#
# #Expanded:      116, #Frontier:    5.268, #Generated:    5.384, Time: 0,075 s, Memory: 114,09 MB
#
#
# #Expanded:      117, #Frontier:    5.302, #Generated:    5.419, Time: 0,076 s, Memory: 114,09 MB
#
#
# #Expanded:      118, #Frontier:    5.377, #Generated:    5.495, Time: 0,076 s, Memory: 114,11 MB
#
#
# #Expanded:      119, #Frontier:    5.417, #Generated:    5.536, Time: 0,076 s, Memory: 114,11 MB
#
#
# #Expanded:      120, #Frontier:    5.492, #Generated:    5.612, Time: 0,077 s, Memory: 114,11 MB
#
#
# #Expanded:      121, #Frontier:    5.539, #Generated:    5.660, Time: 0,077 s, Memory: 114,11 MB
#
#
# #Expanded:      122, #Frontier:    5.568, #Generated:    5.690, Time: 0,077 s, Memory: 114,11 MB
#
#
# #Expanded:      123, #Frontier:    5.622, #Generated:    5.745, Time: 0,078 s, Memory: 114,11 MB
#
#
# #Expanded:      124, #Frontier:    5.693, #Generated:    5.817, Time: 0,078 s, Memory: 114,11 MB
#
#
# #Expanded:      125, #Frontier:    5.737, #Generated:    5.862, Time: 0,079 s, Memory: 114,11 MB
#
#
# #Expanded:      126, #Frontier:    5.811, #Generated:    5.937, Time: 0,079 s, Memory: 114,11 MB
#
#
# #Expanded:      127, #Frontier:    5.847, #Generated:    5.974, Time: 0,079 s, Memory: 114,11 MB
#
#
# #Expanded:      128, #Frontier:    5.880, #Generated:    6.008, Time: 0,079 s, Memory: 114,11 MB
#
#
# #Expanded:      129, #Frontier:    5.911, #Generated:    6.040, Time: 0,080 s, Memory: 114,11 MB
#
#
# #Expanded:      130, #Frontier:    5.944, #Generated:    6.074, Time: 0,080 s, Memory: 114,11 MB
#
#
# #Expanded:      131, #Frontier:    6.012, #Generated:    6.143, Time: 0,080 s, Memory: 114,11 MB
#
#
# #Expanded:      132, #Frontier:    6.080, #Generated:    6.212, Time: 0,080 s, Memory: 114,11 MB
#
#
# #Expanded:      133, #Frontier:    6.134, #Generated:    6.267, Time: 0,081 s, Memory: 114,11 MB
#
#
# #Expanded:      134, #Frontier:    6.169, #Generated:    6.303, Time: 0,081 s, Memory: 114,11 MB
#
#
# #Expanded:      135, #Frontier:    6.215, #Generated:    6.350, Time: 0,081 s, Memory: 114,11 MB
#
#
# #Expanded:      136, #Frontier:    6.252, #Generated:    6.388, Time: 0,081 s, Memory: 114,11 MB
#
#
# #Expanded:      137, #Frontier:    6.295, #Generated:    6.432, Time: 0,082 s, Memory: 114,11 MB
#
#
# #Expanded:      138, #Frontier:    6.346, #Generated:    6.484, Time: 0,082 s, Memory: 114,11 MB
#
#
# #Expanded:      139, #Frontier:    6.421, #Generated:    6.560, Time: 0,082 s, Memory: 114,11 MB
#
#
# #Expanded:      140, #Frontier:    6.485, #Generated:    6.625, Time: 0,083 s, Memory: 114,11 MB
#
#
# #Expanded:      141, #Frontier:    6.533, #Generated:    6.674, Time: 0,083 s, Memory: 114,11 MB
#
#
# #Expanded:      142, #Frontier:    6.601, #Generated:    6.743, Time: 0,084 s, Memory: 114,11 MB
#
#
# #Expanded:      143, #Frontier:    6.662, #Generated:    6.805, Time: 0,084 s, Memory: 114,11 MB
#
#
# #Expanded:      144, #Frontier:    6.705, #Generated:    6.849, Time: 0,084 s, Memory: 114,11 MB
#
#
# #Expanded:      145, #Frontier:    6.730, #Generated:    6.875, Time: 0,084 s, Memory: 114,11 MB
#
#
# #Expanded:      146, #Frontier:    6.737, #Generated:    6.883, Time: 0,084 s, Memory: 114,11 MB
#
#
# #Expanded:      147, #Frontier:    6.769, #Generated:    6.916, Time: 0,085 s, Memory: 114,11 MB
#
#
# #Expanded:      148, #Frontier:    6.793, #Generated:    6.941, Time: 0,085 s, Memory: 114,11 MB
#
#
# #Expanded:      149, #Frontier:    6.818, #Generated:    6.967, Time: 0,085 s, Memory: 114,11 MB
#
#
# #Expanded:      150, #Frontier:    6.850, #Generated:    7.000, Time: 0,086 s, Memory: 114,11 MB
#
#
# #Expanded:      151, #Frontier:    6.912, #Generated:    7.063, Time: 0,086 s, Memory: 114,11 MB
#
#
# #Expanded:      152, #Frontier:    6.973, #Generated:    7.125, Time: 0,086 s, Memory: 114,11 MB
#
#
# #Expanded:      153, #Frontier:    7.038, #Generated:    7.191, Time: 0,087 s, Memory: 114,11 MB
#
#
# #Expanded:      154, #Frontier:    7.071, #Generated:    7.225, Time: 0,087 s, Memory: 114,11 MB
#
#
# #Expanded:      155, #Frontier:    7.114, #Generated:    7.269, Time: 0,087 s, Memory: 114,11 MB
#
#
# #Expanded:      156, #Frontier:    7.145, #Generated:    7.301, Time: 0,087 s, Memory: 114,11 MB
#
#
# #Expanded:      157, #Frontier:    7.200, #Generated:    7.357, Time: 0,088 s, Memory: 114,11 MB
#
#
# #Expanded:      158, #Frontier:    7.241, #Generated:    7.399, Time: 0,088 s, Memory: 114,11 MB
#
#
# #Expanded:      159, #Frontier:    7.316, #Generated:    7.475, Time: 0,088 s, Memory: 114,11 MB
#
#
# #Expanded:      160, #Frontier:    7.386, #Generated:    7.546, Time: 0,089 s, Memory: 114,11 MB
#
#
# #Expanded:      161, #Frontier:    7.469, #Generated:    7.630, Time: 0,089 s, Memory: 114,11 MB
#
#
# #Expanded:      162, #Frontier:    7.545, #Generated:    7.707, Time: 0,089 s, Memory: 114,11 MB
#
#
# #Expanded:      163, #Frontier:    7.610, #Generated:    7.773, Time: 0,090 s, Memory: 114,11 MB
#
#
# #Expanded:      164, #Frontier:    7.689, #Generated:    7.853, Time: 0,090 s, Memory: 114,11 MB
#
#
# #Expanded:      165, #Frontier:    7.724, #Generated:    7.889, Time: 0,090 s, Memory: 114,11 MB
#
#
# #Expanded:      166, #Frontier:    7.792, #Generated:    7.958, Time: 0,091 s, Memory: 114,11 MB
#
#
# #Expanded:      167, #Frontier:    7.811, #Generated:    7.978, Time: 0,091 s, Memory: 114,11 MB
#
#
# #Expanded:      168, #Frontier:    7.835, #Generated:    8.003, Time: 0,091 s, Memory: 114,11 MB
#
#
# #Expanded:      169, #Frontier:    7.908, #Generated:    8.077, Time: 0,091 s, Memory: 114,11 MB
#
#
# #Expanded:      170, #Frontier:    7.936, #Generated:    8.106, Time: 0,091 s, Memory: 114,11 MB
#
#
# #Expanded:      171, #Frontier:    7.972, #Generated:    8.143, Time: 0,092 s, Memory: 114,11 MB
#
#
# #Expanded:      172, #Frontier:    8.025, #Generated:    8.197, Time: 0,092 s, Memory: 114,11 MB
#
#
# #Expanded:      173, #Frontier:    8.075, #Generated:    8.248, Time: 0,092 s, Memory: 114,11 MB
#
#
# #Expanded:      174, #Frontier:    8.106, #Generated:    8.280, Time: 0,093 s, Memory: 114,11 MB
#
#
# #Expanded:      175, #Frontier:    8.141, #Generated:    8.316, Time: 0,093 s, Memory: 114,11 MB
#
#
# #Expanded:      176, #Frontier:    8.162, #Generated:    8.338, Time: 0,093 s, Memory: 114,11 MB
#
#
# #Expanded:      177, #Frontier:    8.194, #Generated:    8.371, Time: 0,093 s, Memory: 114,11 MB
#
#
# #Expanded:      178, #Frontier:    8.221, #Generated:    8.399, Time: 0,093 s, Memory: 114,11 MB
#
#
# #Expanded:      179, #Frontier:    8.240, #Generated:    8.419, Time: 0,094 s, Memory: 114,11 MB
#
#
# #Expanded:      180, #Frontier:    8.276, #Generated:    8.456, Time: 0,094 s, Memory: 114,11 MB
#
#
# #Expanded:      181, #Frontier:    8.302, #Generated:    8.483, Time: 0,094 s, Memory: 114,11 MB
#
#
# #Expanded:      182, #Frontier:    8.355, #Generated:    8.537, Time: 0,094 s, Memory: 114,11 MB
#
#
# #Expanded:      183, #Frontier:    8.381, #Generated:    8.564, Time: 0,095 s, Memory: 114,11 MB
#
#
# #Expanded:      184, #Frontier:    8.415, #Generated:    8.599, Time: 0,095 s, Memory: 114,11 MB
#
#
# #Expanded:      185, #Frontier:    8.466, #Generated:    8.651, Time: 0,095 s, Memory: 114,11 MB
#
#
# #Expanded:      186, #Frontier:    8.487, #Generated:    8.673, Time: 0,095 s, Memory: 114,11 MB
#
#
# #Expanded:      187, #Frontier:    8.514, #Generated:    8.701, Time: 0,096 s, Memory: 114,11 MB
#
#
# #Expanded:      188, #Frontier:    8.536, #Generated:    8.724, Time: 0,096 s, Memory: 114,11 MB
#
#
# #Expanded:      189, #Frontier:    8.560, #Generated:    8.749, Time: 0,096 s, Memory: 114,11 MB
#
#
# #Expanded:      190, #Frontier:    8.592, #Generated:    8.782, Time: 0,096 s, Memory: 114,11 MB
#
#
# #Expanded:      191, #Frontier:    8.624, #Generated:    8.815, Time: 0,097 s, Memory: 114,11 MB
#
#
# #Expanded:      192, #Frontier:    8.641, #Generated:    8.833, Time: 0,097 s, Memory: 114,11 MB
#
#
# #Expanded:      193, #Frontier:    8.695, #Generated:    8.888, Time: 0,097 s, Memory: 114,11 MB
#
#
# #Expanded:      194, #Frontier:    8.748, #Generated:    8.942, Time: 0,097 s, Memory: 114,11 MB
#
#
# #Expanded:      195, #Frontier:    8.774, #Generated:    8.969, Time: 0,098 s, Memory: 114,11 MB
#
#
# #Expanded:      196, #Frontier:    8.789, #Generated:    8.985, Time: 0,098 s, Memory: 114,11 MB
#
#
# #Expanded:      197, #Frontier:    8.832, #Generated:    9.029, Time: 0,098 s, Memory: 114,11 MB
#
#
# #Expanded:      198, #Frontier:    8.890, #Generated:    9.088, Time: 0,098 s, Memory: 114,11 MB
#
#
# #Expanded:      199, #Frontier:    8.928, #Generated:    9.127, Time: 0,099 s, Memory: 114,11 MB
#
#
# #Expanded:      200, #Frontier:    8.993, #Generated:    9.193, Time: 0,099 s, Memory: 114,11 MB
#
#
# #Expanded:      201, #Frontier:    9.036, #Generated:    9.237, Time: 0,099 s, Memory: 114,11 MB
#
#
# #Expanded:      202, #Frontier:    9.065, #Generated:    9.267, Time: 0,099 s, Memory: 114,12 MB
#
#
# #Expanded:      203, #Frontier:    9.112, #Generated:    9.315, Time: 0,100 s, Memory: 114,12 MB
#
#
# #Expanded:      204, #Frontier:    9.178, #Generated:    9.382, Time: 0,100 s, Memory: 114,16 MB
#
#
# #Expanded:      205, #Frontier:    9.223, #Generated:    9.428, Time: 0,100 s, Memory: 114,16 MB
#
#
# #Expanded:      206, #Frontier:    9.260, #Generated:    9.466, Time: 0,100 s, Memory: 114,16 MB
#
#
# #Expanded:      207, #Frontier:    9.277, #Generated:    9.484, Time: 0,101 s, Memory: 114,16 MB
#
#
# #Expanded:      208, #Frontier:    9.305, #Generated:    9.513, Time: 0,101 s, Memory: 114,16 MB
#
#
# #Expanded:      209, #Frontier:    9.319, #Generated:    9.528, Time: 0,101 s, Memory: 114,16 MB
#
#
# #Expanded:      210, #Frontier:    9.330, #Generated:    9.540, Time: 0,101 s, Memory: 114,16 MB
#
#
# #Expanded:      211, #Frontier:    9.345, #Generated:    9.556, Time: 0,101 s, Memory: 114,16 MB
#
#
# #Expanded:      212, #Frontier:    9.368, #Generated:    9.580, Time: 0,101 s, Memory: 114,16 MB
#
#
# #Expanded:      213, #Frontier:    9.411, #Generated:    9.624, Time: 0,102 s, Memory: 114,16 MB
#
#
# #Expanded:      214, #Frontier:    9.438, #Generated:    9.652, Time: 0,102 s, Memory: 114,16 MB
#
#
# #Expanded:      215, #Frontier:    9.459, #Generated:    9.674, Time: 0,102 s, Memory: 114,16 MB
#
#
# #Expanded:      216, #Frontier:    9.482, #Generated:    9.698, Time: 0,103 s, Memory: 114,16 MB
#
#
# #Expanded:      217, #Frontier:    9.505, #Generated:    9.722, Time: 0,103 s, Memory: 114,16 MB
#
#
# #Expanded:      218, #Frontier:    9.512, #Generated:    9.730, Time: 0,103 s, Memory: 114,16 MB
#
#
# #Expanded:      219, #Frontier:    9.556, #Generated:    9.775, Time: 0,103 s, Memory: 114,16 MB
#
#
# #Expanded:      220, #Frontier:    9.586, #Generated:    9.806, Time: 0,104 s, Memory: 114,16 MB
#
#
# #Expanded:      221, #Frontier:    9.614, #Generated:    9.835, Time: 0,104 s, Memory: 114,16 MB
#
#
# #Expanded:      222, #Frontier:    9.662, #Generated:    9.884, Time: 0,104 s, Memory: 114,16 MB
#
#
# #Expanded:      223, #Frontier:    9.697, #Generated:    9.920, Time: 0,104 s, Memory: 114,16 MB
#
#
# #Expanded:      224, #Frontier:    9.715, #Generated:    9.939, Time: 0,105 s, Memory: 114,16 MB
#
#
# #Expanded:      225, #Frontier:    9.746, #Generated:    9.971, Time: 0,105 s, Memory: 114,16 MB
#
#
# #Expanded:      226, #Frontier:    9.772, #Generated:    9.998, Time: 0,105 s, Memory: 114,16 MB
#
#
# #Expanded:      227, #Frontier:    9.787, #Generated:   10.014, Time: 0,105 s, Memory: 114,16 MB
#
#
# #Expanded:      228, #Frontier:    9.856, #Generated:   10.084, Time: 0,106 s, Memory: 114,16 MB
#
#
# #Expanded:      229, #Frontier:    9.921, #Generated:   10.150, Time: 0,106 s, Memory: 114,16 MB
#
#
# #Expanded:      230, #Frontier:    9.967, #Generated:   10.197, Time: 0,106 s, Memory: 114,16 MB
#
#
# #Expanded:      231, #Frontier:   10.010, #Generated:   10.241, Time: 0,107 s, Memory: 114,16 MB
#
#
# #Expanded:      232, #Frontier:   10.053, #Generated:   10.285, Time: 0,107 s, Memory: 114,17 MB
#
#
# #Expanded:      233, #Frontier:   10.088, #Generated:   10.321, Time: 0,107 s, Memory: 114,17 MB
#
#
# #Expanded:      234, #Frontier:   10.179, #Generated:   10.413, Time: 0,108 s, Memory: 114,17 MB
#
#
# #Expanded:      235, #Frontier:   10.242, #Generated:   10.477, Time: 0,108 s, Memory: 114,17 MB
#
#
# #Expanded:      236, #Frontier:   10.337, #Generated:   10.573, Time: 0,108 s, Memory: 114,17 MB
#
#
# #Expanded:      237, #Frontier:   10.403, #Generated:   10.640, Time: 0,109 s, Memory: 114,17 MB
#
#
# #Expanded:      238, #Frontier:   10.425, #Generated:   10.663, Time: 0,109 s, Memory: 114,17 MB
#
#
# #Expanded:      239, #Frontier:   10.479, #Generated:   10.718, Time: 0,109 s, Memory: 114,17 MB
#
#
# #Expanded:      240, #Frontier:   10.516, #Generated:   10.756, Time: 0,110 s, Memory: 114,17 MB
#
#
# #Expanded:      241, #Frontier:   10.554, #Generated:   10.795, Time: 0,110 s, Memory: 114,17 MB
#
#
# #Expanded:      242, #Frontier:   10.609, #Generated:   10.851, Time: 0,110 s, Memory: 114,17 MB
#
#
# #Expanded:      243, #Frontier:   10.631, #Generated:   10.874, Time: 0,110 s, Memory: 114,17 MB
#
#
# #Expanded:      244, #Frontier:   10.643, #Generated:   10.887, Time: 0,110 s, Memory: 114,17 MB
#
#
# #Expanded:      245, #Frontier:   10.660, #Generated:   10.905, Time: 0,110 s, Memory: 114,19 MB
#
#
# #Expanded:      246, #Frontier:   10.673, #Generated:   10.919, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      247, #Frontier:   10.675, #Generated:   10.922, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      248, #Frontier:   10.677, #Generated:   10.925, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      249, #Frontier:   10.681, #Generated:   10.930, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      250, #Frontier:   10.686, #Generated:   10.936, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      251, #Frontier:   10.692, #Generated:   10.943, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      252, #Frontier:   10.722, #Generated:   10.974, Time: 0,111 s, Memory: 114,19 MB
#
#
# #Expanded:      253, #Frontier:   10.743, #Generated:   10.996, Time: 0,112 s, Memory: 114,19 MB
#
#
# #Expanded:      254, #Frontier:   10.778, #Generated:   11.032, Time: 0,112 s, Memory: 114,19 MB
#
#
# #Expanded:      255, #Frontier:   10.827, #Generated:   11.082, Time: 0,112 s, Memory: 114,19 MB
#
#
# #Expanded:      256, #Frontier:   10.875, #Generated:   11.131, Time: 0,112 s, Memory: 114,19 MB
#
#
# #Expanded:      257, #Frontier:   10.938, #Generated:   11.195, Time: 0,113 s, Memory: 114,19 MB
#
#
# #Expanded:      258, #Frontier:   10.965, #Generated:   11.223, Time: 0,113 s, Memory: 114,19 MB
#
#
# #Expanded:      259, #Frontier:   11.030, #Generated:   11.289, Time: 0,113 s, Memory: 114,19 MB
#
#
# #Expanded:      260, #Frontier:   11.085, #Generated:   11.345, Time: 0,114 s, Memory: 114,19 MB
#
#
# #Expanded:      261, #Frontier:   11.130, #Generated:   11.391, Time: 0,114 s, Memory: 114,19 MB
#
#
# #Expanded:      262, #Frontier:   11.163, #Generated:   11.425, Time: 0,114 s, Memory: 114,19 MB
#
#
# #Expanded:      263, #Frontier:   11.183, #Generated:   11.446, Time: 0,114 s, Memory: 114,19 MB
#
#
# #Expanded:      264, #Frontier:   11.226, #Generated:   11.490, Time: 0,115 s, Memory: 114,19 MB
#
#
# #Expanded:      265, #Frontier:   11.255, #Generated:   11.520, Time: 0,115 s, Memory: 114,19 MB
#
#
# #Expanded:      266, #Frontier:   11.293, #Generated:   11.559, Time: 0,115 s, Memory: 114,19 MB
#
#
# #Expanded:      267, #Frontier:   11.331, #Generated:   11.598, Time: 0,116 s, Memory: 114,19 MB
#
#
# #Expanded:      268, #Frontier:   11.368, #Generated:   11.636, Time: 0,116 s, Memory: 114,19 MB
#
#
# #Expanded:      269, #Frontier:   11.406, #Generated:   11.675, Time: 0,116 s, Memory: 114,19 MB
#
#
# #Expanded:      270, #Frontier:   11.417, #Generated:   11.687, Time: 0,116 s, Memory: 114,19 MB
#
#
# #Expanded:      271, #Frontier:   11.435, #Generated:   11.706, Time: 0,117 s, Memory: 114,19 MB
#
#
# #Expanded:      272, #Frontier:   11.464, #Generated:   11.736, Time: 0,117 s, Memory: 114,19 MB
#
#
# #Expanded:      273, #Frontier:   11.480, #Generated:   11.753, Time: 0,117 s, Memory: 114,19 MB
#
#
# #Expanded:      274, #Frontier:   11.491, #Generated:   11.765, Time: 0,117 s, Memory: 114,19 MB
#
#
# #Expanded:      275, #Frontier:   11.500, #Generated:   11.775, Time: 0,117 s, Memory: 114,19 MB
#
#
# #Expanded:      276, #Frontier:   11.513, #Generated:   11.789, Time: 0,117 s, Memory: 114,19 MB
#
#
# #Expanded:      277, #Frontier:   11.551, #Generated:   11.828, Time: 0,118 s, Memory: 114,19 MB
#
#
# #Expanded:      278, #Frontier:   11.568, #Generated:   11.846, Time: 0,118 s, Memory: 114,19 MB
#
#
# #Expanded:      279, #Frontier:   11.604, #Generated:   11.883, Time: 0,118 s, Memory: 114,19 MB
#
#
# #Expanded:      280, #Frontier:   11.633, #Generated:   11.913, Time: 0,118 s, Memory: 114,19 MB
#
#
# #Expanded:      281, #Frontier:   11.661, #Generated:   11.942, Time: 0,119 s, Memory: 114,19 MB
#
#
# #Expanded:      282, #Frontier:   11.695, #Generated:   11.977, Time: 0,119 s, Memory: 114,19 MB
#
#
# #Expanded:      283, #Frontier:   11.733, #Generated:   12.016, Time: 0,119 s, Memory: 114,19 MB
#
#
# #Expanded:      284, #Frontier:   11.756, #Generated:   12.040, Time: 0,119 s, Memory: 114,19 MB
#
#
# #Expanded:      285, #Frontier:   11.763, #Generated:   12.048, Time: 0,120 s, Memory: 114,19 MB
#
#
# #Expanded:      286, #Frontier:   11.810, #Generated:   12.096, Time: 0,120 s, Memory: 114,19 MB
#
#
# #Expanded:      287, #Frontier:   11.845, #Generated:   12.132, Time: 0,120 s, Memory: 114,19 MB
#
#
# #Expanded:      288, #Frontier:   11.884, #Generated:   12.172, Time: 0,121 s, Memory: 114,19 MB
#
#
# #Expanded:      289, #Frontier:   11.952, #Generated:   12.241, Time: 0,121 s, Memory: 114,19 MB
#
#
# #Expanded:      290, #Frontier:   11.994, #Generated:   12.284, Time: 0,121 s, Memory: 114,23 MB
#
#
# #Expanded:      291, #Frontier:   12.035, #Generated:   12.326, Time: 0,121 s, Memory: 114,23 MB
#
#
# #Expanded:      292, #Frontier:   12.074, #Generated:   12.366, Time: 0,122 s, Memory: 114,23 MB
#
#
# #Expanded:      293, #Frontier:   12.104, #Generated:   12.397, Time: 0,122 s, Memory: 114,23 MB
#
#
# #Expanded:      294, #Frontier:   12.146, #Generated:   12.440, Time: 0,122 s, Memory: 114,23 MB
#
#
# #Expanded:      295, #Frontier:   12.180, #Generated:   12.475, Time: 0,122 s, Memory: 114,23 MB
#
#
# #Expanded:      296, #Frontier:   12.234, #Generated:   12.530, Time: 0,123 s, Memory: 114,23 MB
#
#
# #Expanded:      297, #Frontier:   12.293, #Generated:   12.590, Time: 0,123 s, Memory: 114,23 MB
#
#
# #Expanded:      298, #Frontier:   12.337, #Generated:   12.635, Time: 0,124 s, Memory: 114,23 MB
#
#
# #Expanded:      299, #Frontier:   12.389, #Generated:   12.688, Time: 0,143 s, Memory: 114,23 MB
#
#
# #Expanded:      300, #Frontier:   12.410, #Generated:   12.710, Time: 0,143 s, Memory: 114,23 MB
#
#
# #Expanded:      301, #Frontier:   12.429, #Generated:   12.730, Time: 0,143 s, Memory: 114,23 MB
#
#
# #Expanded:      302, #Frontier:   12.476, #Generated:   12.778, Time: 0,143 s, Memory: 114,23 MB
#
#
# #Expanded:      303, #Frontier:   12.475, #Generated:   12.778, Time: 0,143 s, Memory: 114,23 MB
#
#
# #Expanded:      304, #Frontier:   12.519, #Generated:   12.823, Time: 0,144 s, Memory: 114,23 MB
#
#
# #Expanded:      305, #Frontier:   12.600, #Generated:   12.905, Time: 0,144 s, Memory: 114,23 MB
#
#
# #Expanded:      306, #Frontier:   12.664, #Generated:   12.970, Time: 0,144 s, Memory: 114,23 MB
#
#
# #Expanded:      307, #Frontier:   12.729, #Generated:   13.036, Time: 0,145 s, Memory: 114,25 MB
#
#
# #Expanded:      308, #Frontier:   12.762, #Generated:   13.070, Time: 0,145 s, Memory: 114,25 MB
#
#
# #Expanded:      309, #Frontier:   12.796, #Generated:   13.105, Time: 0,145 s, Memory: 114,25 MB
#
#
# #Expanded:      310, #Frontier:   12.830, #Generated:   13.140, Time: 0,145 s, Memory: 114,25 MB
#
#
# #Expanded:      311, #Frontier:   12.874, #Generated:   13.185, Time: 0,146 s, Memory: 114,25 MB
#
#
# #Expanded:      312, #Frontier:   12.919, #Generated:   13.231, Time: 0,146 s, Memory: 114,25 MB
#
#
# #Expanded:      313, #Frontier:   12.975, #Generated:   13.288, Time: 0,146 s, Memory: 114,25 MB
#
#
# #Expanded:      314, #Frontier:   13.034, #Generated:   13.348, Time: 0,146 s, Memory: 114,25 MB
#
#
# #Expanded:      315, #Frontier:   13.085, #Generated:   13.400, Time: 0,147 s, Memory: 114,25 MB
#
#
# #Expanded:      316, #Frontier:   13.120, #Generated:   13.436, Time: 0,147 s, Memory: 114,25 MB
#
#
# #Expanded:      317, #Frontier:   13.189, #Generated:   13.506, Time: 0,147 s, Memory: 114,25 MB
#
#
# #Expanded:      318, #Frontier:   13.239, #Generated:   13.557, Time: 0,147 s, Memory: 114,25 MB
#
#
# #Expanded:      319, #Frontier:   13.325, #Generated:   13.644, Time: 0,148 s, Memory: 114,27 MB
#
#
# #Expanded:      320, #Frontier:   13.368, #Generated:   13.688, Time: 0,148 s, Memory: 114,27 MB
#
#
# #Expanded:      321, #Frontier:   13.411, #Generated:   13.732, Time: 0,149 s, Memory: 114,27 MB
#
#
# #Expanded:      322, #Frontier:   13.477, #Generated:   13.799, Time: 0,149 s, Memory: 114,27 MB
#
#
# #Expanded:      323, #Frontier:   13.524, #Generated:   13.847, Time: 0,149 s, Memory: 114,27 MB
#
#
# #Expanded:      324, #Frontier:   13.560, #Generated:   13.884, Time: 0,149 s, Memory: 114,27 MB
#
#
# #Expanded:      325, #Frontier:   13.596, #Generated:   13.921, Time: 0,150 s, Memory: 114,27 MB
#
#
# #Expanded:      326, #Frontier:   13.636, #Generated:   13.962, Time: 0,150 s, Memory: 114,27 MB
#
#
# #Expanded:      327, #Frontier:   13.689, #Generated:   14.016, Time: 0,150 s, Memory: 114,27 MB
#
#
# #Expanded:      328, #Frontier:   13.706, #Generated:   14.034, Time: 0,150 s, Memory: 114,27 MB
#
#
# #Expanded:      329, #Frontier:   13.728, #Generated:   14.057, Time: 0,150 s, Memory: 114,27 MB
#
#
# #Expanded:      330, #Frontier:   13.748, #Generated:   14.078, Time: 0,151 s, Memory: 114,27 MB
#
#
# #Expanded:      331, #Frontier:   13.801, #Generated:   14.132, Time: 0,151 s, Memory: 114,27 MB
#
#
# #Expanded:      332, #Frontier:   13.865, #Generated:   14.197, Time: 0,151 s, Memory: 114,27 MB
#
#
# #Expanded:      333, #Frontier:   13.902, #Generated:   14.235, Time: 0,151 s, Memory: 114,27 MB
#
#
# #Expanded:      334, #Frontier:   13.937, #Generated:   14.271, Time: 0,151 s, Memory: 114,27 MB
#
#
# #Expanded:      335, #Frontier:   13.984, #Generated:   14.319, Time: 0,152 s, Memory: 114,27 MB
#
#
# #Expanded:      336, #Frontier:   14.047, #Generated:   14.383, Time: 0,152 s, Memory: 114,27 MB
#
#
# #Expanded:      337, #Frontier:   14.112, #Generated:   14.449, Time: 0,152 s, Memory: 114,27 MB
#
#
# #Expanded:      338, #Frontier:   14.169, #Generated:   14.507, Time: 0,152 s, Memory: 114,27 MB
#
#
# #Expanded:      339, #Frontier:   14.215, #Generated:   14.554, Time: 0,153 s, Memory: 114,27 MB
#
#
# #Expanded:      340, #Frontier:   14.246, #Generated:   14.586, Time: 0,153 s, Memory: 114,27 MB
#
#
# #Expanded:      341, #Frontier:   14.273, #Generated:   14.614, Time: 0,153 s, Memory: 114,27 MB
#
#
# #Expanded:      342, #Frontier:   14.322, #Generated:   14.664, Time: 0,153 s, Memory: 114,27 MB
#
#
# #Expanded:      343, #Frontier:   14.362, #Generated:   14.705, Time: 0,154 s, Memory: 114,27 MB
#
#
# #Expanded:      344, #Frontier:   14.438, #Generated:   14.782, Time: 0,154 s, Memory: 114,27 MB
#
#
# #Expanded:      345, #Frontier:   14.460, #Generated:   14.805, Time: 0,154 s, Memory: 114,27 MB
#
#
# #Expanded:      346, #Frontier:   14.509, #Generated:   14.855, Time: 0,155 s, Memory: 114,27 MB
#
#
# #Expanded:      347, #Frontier:   14.532, #Generated:   14.879, Time: 0,155 s, Memory: 114,27 MB
#
#
# #Expanded:      348, #Frontier:   14.579, #Generated:   14.927, Time: 0,155 s, Memory: 114,27 MB
#
#
# #Expanded:      349, #Frontier:   14.648, #Generated:   14.997, Time: 0,155 s, Memory: 114,27 MB
#
#
# #Expanded:      350, #Frontier:   14.690, #Generated:   15.040, Time: 0,156 s, Memory: 114,27 MB
#
#
# #Expanded:      351, #Frontier:   14.741, #Generated:   15.092, Time: 0,156 s, Memory: 114,27 MB
#
#
# #Expanded:      352, #Frontier:   14.772, #Generated:   15.124, Time: 0,156 s, Memory: 114,27 MB
#
#
# #Expanded:      353, #Frontier:   14.825, #Generated:   15.178, Time: 0,157 s, Memory: 114,27 MB
#
#
# #Expanded:      354, #Frontier:   14.840, #Generated:   15.194, Time: 0,157 s, Memory: 114,27 MB
#
#
# #Expanded:      355, #Frontier:   14.895, #Generated:   15.250, Time: 0,157 s, Memory: 114,27 MB
#
#
# #Expanded:      356, #Frontier:   14.939, #Generated:   15.295, Time: 0,157 s, Memory: 114,27 MB
#
#
# #Expanded:      357, #Frontier:   14.940, #Generated:   15.297, Time: 0,157 s, Memory: 114,27 MB
#
#
# #Expanded:      358, #Frontier:   14.995, #Generated:   15.353, Time: 0,157 s, Memory: 114,27 MB
#
#
# #Expanded:      359, #Frontier:   15.066, #Generated:   15.425, Time: 0,158 s, Memory: 114,28 MB
#
#
# #Expanded:      360, #Frontier:   15.101, #Generated:   15.461, Time: 0,158 s, Memory: 114,28 MB
#
#
# #Expanded:      361, #Frontier:   15.146, #Generated:   15.507, Time: 0,158 s, Memory: 114,28 MB
#
#
# #Expanded:      362, #Frontier:   15.182, #Generated:   15.544, Time: 0,158 s, Memory: 114,28 MB
#
#
# #Expanded:      363, #Frontier:   15.199, #Generated:   15.562, Time: 0,159 s, Memory: 114,28 MB
#
#
# #Expanded:      364, #Frontier:   15.227, #Generated:   15.591, Time: 0,159 s, Memory: 114,28 MB
#
#
# #Expanded:      365, #Frontier:   15.249, #Generated:   15.614, Time: 0,159 s, Memory: 114,28 MB
#
#
# #Expanded:      366, #Frontier:   15.263, #Generated:   15.629, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      367, #Frontier:   15.297, #Generated:   15.664, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      368, #Frontier:   15.332, #Generated:   15.700, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      369, #Frontier:   15.335, #Generated:   15.704, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      370, #Frontier:   15.342, #Generated:   15.712, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      371, #Frontier:   15.350, #Generated:   15.721, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      372, #Frontier:   15.373, #Generated:   15.745, Time: 0,160 s, Memory: 114,28 MB
#
#
# #Expanded:      373, #Frontier:   15.414, #Generated:   15.787, Time: 0,161 s, Memory: 114,28 MB
#
#
# #Expanded:      374, #Frontier:   15.429, #Generated:   15.803, Time: 0,161 s, Memory: 114,28 MB
#
#
# #Expanded:      375, #Frontier:   15.446, #Generated:   15.821, Time: 0,161 s, Memory: 114,28 MB
#
#
# #Expanded:      376, #Frontier:   15.466, #Generated:   15.842, Time: 0,161 s, Memory: 114,28 MB
#
#
# #Expanded:      377, #Frontier:   15.507, #Generated:   15.884, Time: 0,162 s, Memory: 114,28 MB
#
#
# #Expanded:      378, #Frontier:   15.559, #Generated:   15.937, Time: 0,162 s, Memory: 114,28 MB
#
#
# #Expanded:      379, #Frontier:   15.589, #Generated:   15.968, Time: 0,162 s, Memory: 114,28 MB
#
#
# #Expanded:      380, #Frontier:   15.636, #Generated:   16.016, Time: 0,162 s, Memory: 114,28 MB
#
#
# #Expanded:      381, #Frontier:   15.647, #Generated:   16.028, Time: 0,163 s, Memory: 114,28 MB
#
#
# #Expanded:      382, #Frontier:   15.672, #Generated:   16.054, Time: 0,163 s, Memory: 114,28 MB
#
#
# #Expanded:      383, #Frontier:   15.718, #Generated:   16.101, Time: 0,163 s, Memory: 114,28 MB
#
#
# #Expanded:      384, #Frontier:   15.778, #Generated:   16.162, Time: 0,163 s, Memory: 114,28 MB
#
#
# #Expanded:      385, #Frontier:   15.857, #Generated:   16.242, Time: 0,164 s, Memory: 114,28 MB
#
#
# #Expanded:      386, #Frontier:   15.938, #Generated:   16.324, Time: 0,164 s, Memory: 114,28 MB
#
#
# #Expanded:      387, #Frontier:   15.977, #Generated:   16.364, Time: 0,164 s, Memory: 114,28 MB
#
#
# #Expanded:      388, #Frontier:   16.015, #Generated:   16.403, Time: 0,165 s, Memory: 114,28 MB
#
#
# #Expanded:      389, #Frontier:   16.091, #Generated:   16.480, Time: 0,165 s, Memory: 114,28 MB
#
#
# #Expanded:      390, #Frontier:   16.158, #Generated:   16.548, Time: 0,165 s, Memory: 114,28 MB
#
#
# #Expanded:      391, #Frontier:   16.190, #Generated:   16.581, Time: 0,166 s, Memory: 114,28 MB
#
#
# #Expanded:      392, #Frontier:   16.217, #Generated:   16.609, Time: 0,166 s, Memory: 114,28 MB
#
#
# #Expanded:      393, #Frontier:   16.271, #Generated:   16.664, Time: 0,166 s, Memory: 114,28 MB
#
#
# #Expanded:      394, #Frontier:   16.301, #Generated:   16.695, Time: 0,166 s, Memory: 114,28 MB
#
#
# #Expanded:      395, #Frontier:   16.329, #Generated:   16.724, Time: 0,167 s, Memory: 114,28 MB
#
#
# #Expanded:      396, #Frontier:   16.370, #Generated:   16.766, Time: 0,167 s, Memory: 114,28 MB
#
#
# #Expanded:      397, #Frontier:   16.411, #Generated:   16.808, Time: 0,167 s, Memory: 114,28 MB
#
#
# #Expanded:      398, #Frontier:   16.440, #Generated:   16.838, Time: 0,167 s, Memory: 114,28 MB
#
#
# #Expanded:      399, #Frontier:   16.475, #Generated:   16.874, Time: 0,167 s, Memory: 114,28 MB
#
#
# #Expanded:      400, #Frontier:   16.511, #Generated:   16.911, Time: 0,168 s, Memory: 114,28 MB
#
#
# #Expanded:      401, #Frontier:   16.556, #Generated:   16.957, Time: 0,168 s, Memory: 114,28 MB
#
#
# #Expanded:      402, #Frontier:   16.613, #Generated:   17.015, Time: 0,168 s, Memory: 114,28 MB
#
#
# #Expanded:      403, #Frontier:   16.660, #Generated:   17.063, Time: 0,168 s, Memory: 114,28 MB
#
#
# #Expanded:      404, #Frontier:   16.705, #Generated:   17.109, Time: 0,168 s, Memory: 114,28 MB
#
#
# #Expanded:      405, #Frontier:   16.746, #Generated:   17.151, Time: 0,169 s, Memory: 114,28 MB
#
#
# #Expanded:      406, #Frontier:   16.752, #Generated:   17.158, Time: 0,169 s, Memory: 114,28 MB
#
#
# #Expanded:      407, #Frontier:   16.767, #Generated:   17.174, Time: 0,169 s, Memory: 114,28 MB
#
#
# #Expanded:      408, #Frontier:   16.832, #Generated:   17.240, Time: 0,169 s, Memory: 114,28 MB
#
#
# #Expanded:      409, #Frontier:   16.851, #Generated:   17.260, Time: 0,169 s, Memory: 114,28 MB
#
#
# #Expanded:      410, #Frontier:   16.868, #Generated:   17.278, Time: 0,170 s, Memory: 114,28 MB
#
#
# #Expanded:      411, #Frontier:   16.917, #Generated:   17.328, Time: 0,170 s, Memory: 114,31 MB
#
#
# #Expanded:      412, #Frontier:   16.944, #Generated:   17.356, Time: 0,170 s, Memory: 114,33 MB
#
#
# #Expanded:      413, #Frontier:   17.003, #Generated:   17.416, Time: 0,170 s, Memory: 114,34 MB
#
#
# #Expanded:      414, #Frontier:   17.052, #Generated:   17.466, Time: 0,170 s, Memory: 114,39 MB
#
#
# #Expanded:      415, #Frontier:   17.071, #Generated:   17.486, Time: 0,171 s, Memory: 114,44 MB
#
#
# #Expanded:      416, #Frontier:   17.120, #Generated:   17.536, Time: 0,171 s, Memory: 114,45 MB
#
#
# #Expanded:      417, #Frontier:   17.142, #Generated:   17.559, Time: 0,171 s, Memory: 114,47 MB
#
#
# #Expanded:      418, #Frontier:   17.178, #Generated:   17.596, Time: 0,172 s, Memory: 114,48 MB
#
#
# #Expanded:      419, #Frontier:   17.191, #Generated:   17.610, Time: 0,172 s, Memory: 114,48 MB
#
#
# #Expanded:      420, #Frontier:   17.234, #Generated:   17.654, Time: 0,172 s, Memory: 114,52 MB
#
#
# #Expanded:      421, #Frontier:   17.295, #Generated:   17.716, Time: 0,172 s, Memory: 114,56 MB
#
#
# #Expanded:      422, #Frontier:   17.328, #Generated:   17.750, Time: 0,172 s, Memory: 114,59 MB
#
#
# #Expanded:      423, #Frontier:   17.352, #Generated:   17.775, Time: 0,173 s, Memory: 114,61 MB
#
#
# #Expanded:      424, #Frontier:   17.377, #Generated:   17.801, Time: 0,173 s, Memory: 114,61 MB
#
#
# #Expanded:      425, #Frontier:   17.421, #Generated:   17.846, Time: 0,173 s, Memory: 114,67 MB
#
#
# #Expanded:      426, #Frontier:   17.484, #Generated:   17.910, Time: 0,174 s, Memory: 114,72 MB
#
#
# #Expanded:      427, #Frontier:   17.516, #Generated:   17.943, Time: 0,174 s, Memory: 114,73 MB
#
#
# #Expanded:      428, #Frontier:   17.562, #Generated:   17.990, Time: 0,174 s, Memory: 114,77 MB
#
#
# #Expanded:      429, #Frontier:   17.607, #Generated:   18.036, Time: 0,174 s, Memory: 114,80 MB
#
#
# #Expanded:      430, #Frontier:   17.612, #Generated:   18.042, Time: 0,175 s, Memory: 114,80 MB
#
#
# #Expanded:      431, #Frontier:   17.628, #Generated:   18.059, Time: 0,175 s, Memory: 114,80 MB
#
#
# #Expanded:      432, #Frontier:   17.677, #Generated:   18.109, Time: 0,175 s, Memory: 114,83 MB
#
#
# #Expanded:      433, #Frontier:   17.708, #Generated:   18.141, Time: 0,175 s, Memory: 114,83 MB
#
#
# #Expanded:      434, #Frontier:   17.758, #Generated:   18.192, Time: 0,176 s, Memory: 114,83 MB
#
#
# #Expanded:      435, #Frontier:   17.801, #Generated:   18.236, Time: 0,176 s, Memory: 114,83 MB
#
#
# #Expanded:      436, #Frontier:   17.856, #Generated:   18.292, Time: 0,176 s, Memory: 114,83 MB
#
#
# #Expanded:      437, #Frontier:   17.911, #Generated:   18.348, Time: 0,177 s, Memory: 114,83 MB
#
#
# #Expanded:      438, #Frontier:   17.929, #Generated:   18.367, Time: 0,177 s, Memory: 114,83 MB
#
#
# #Expanded:      439, #Frontier:   17.959, #Generated:   18.398, Time: 0,177 s, Memory: 114,83 MB
#
#
# #Expanded:      440, #Frontier:   17.991, #Generated:   18.431, Time: 0,177 s, Memory: 114,83 MB
#
#
# #Expanded:      441, #Frontier:   18.014, #Generated:   18.455, Time: 0,177 s, Memory: 114,83 MB
#
#
# #Expanded:      442, #Frontier:   18.043, #Generated:   18.485, Time: 0,178 s, Memory: 114,83 MB
#
#
# #Expanded:      443, #Frontier:   18.053, #Generated:   18.496, Time: 0,178 s, Memory: 114,83 MB
#
#
# #Expanded:      444, #Frontier:   18.080, #Generated:   18.524, Time: 0,178 s, Memory: 114,83 MB
#
#
# #Expanded:      445, #Frontier:   18.109, #Generated:   18.554, Time: 0,178 s, Memory: 114,83 MB
#
#
# #Expanded:      446, #Frontier:   18.160, #Generated:   18.606, Time: 0,178 s, Memory: 114,83 MB
#
#
# #Expanded:      447, #Frontier:   18.227, #Generated:   18.674, Time: 0,179 s, Memory: 114,83 MB
#
#
# #Expanded:      448, #Frontier:   18.278, #Generated:   18.726, Time: 0,179 s, Memory: 114,83 MB
#
#
# #Expanded:      449, #Frontier:   18.291, #Generated:   18.740, Time: 0,179 s, Memory: 114,83 MB
#
#
# #Expanded:      450, #Frontier:   18.302, #Generated:   18.752, Time: 0,179 s, Memory: 114,83 MB
#
#
# #Expanded:      451, #Frontier:   18.322, #Generated:   18.773, Time: 0,179 s, Memory: 114,83 MB
#
#
# #Expanded:      452, #Frontier:   18.367, #Generated:   18.819, Time: 0,180 s, Memory: 114,83 MB
#
#
# #Expanded:      453, #Frontier:   18.383, #Generated:   18.836, Time: 0,180 s, Memory: 114,83 MB
#
#
# #Expanded:      454, #Frontier:   18.423, #Generated:   18.877, Time: 0,180 s, Memory: 114,84 MB
#
#
# #Expanded:      455, #Frontier:   18.461, #Generated:   18.916, Time: 0,180 s, Memory: 114,84 MB
#
#
# #Expanded:      456, #Frontier:   18.499, #Generated:   18.955, Time: 0,181 s, Memory: 114,84 MB
#
#
# #Expanded:      457, #Frontier:   18.541, #Generated:   18.998, Time: 0,181 s, Memory: 114,84 MB
#
#
# #Expanded:      458, #Frontier:   18.602, #Generated:   19.060, Time: 0,181 s, Memory: 114,84 MB
#
#
# #Expanded:      459, #Frontier:   18.638, #Generated:   19.097, Time: 0,182 s, Memory: 114,84 MB
#
#
# #Expanded:      460, #Frontier:   18.671, #Generated:   19.131, Time: 0,182 s, Memory: 114,84 MB
#
#
# #Expanded:      461, #Frontier:   18.690, #Generated:   19.151, Time: 0,182 s, Memory: 114,84 MB
#
#
# #Expanded:      462, #Frontier:   18.700, #Generated:   19.162, Time: 0,182 s, Memory: 114,84 MB
#
#
# #Expanded:      463, #Frontier:   18.732, #Generated:   19.195, Time: 0,183 s, Memory: 114,84 MB
#
#
# #Expanded:      464, #Frontier:   18.776, #Generated:   19.240, Time: 0,183 s, Memory: 114,84 MB
#
#
# #Expanded:      465, #Frontier:   18.807, #Generated:   19.272, Time: 0,183 s, Memory: 114,84 MB
#
#
# #Expanded:      466, #Frontier:   18.834, #Generated:   19.300, Time: 0,183 s, Memory: 114,84 MB
#
#
# #Expanded:      467, #Frontier:   18.857, #Generated:   19.324, Time: 0,183 s, Memory: 114,84 MB
#
#
# #Expanded:      468, #Frontier:   18.897, #Generated:   19.365, Time: 0,184 s, Memory: 114,84 MB
#
#
# #Expanded:      469, #Frontier:   18.923, #Generated:   19.392, Time: 0,184 s, Memory: 114,84 MB
#
#
# #Expanded:      470, #Frontier:   18.940, #Generated:   19.410, Time: 0,184 s, Memory: 114,84 MB
#
#
# #Expanded:      471, #Frontier:   18.957, #Generated:   19.428, Time: 0,184 s, Memory: 114,84 MB
#
#
# #Expanded:      472, #Frontier:   18.986, #Generated:   19.458, Time: 0,185 s, Memory: 114,84 MB
#
#
# #Expanded:      473, #Frontier:   18.996, #Generated:   19.469, Time: 0,185 s, Memory: 114,84 MB
#
#
# #Expanded:      474, #Frontier:   18.997, #Generated:   19.471, Time: 0,185 s, Memory: 114,84 MB
#
#
# #Expanded:      475, #Frontier:   19.019, #Generated:   19.494, Time: 0,185 s, Memory: 114,84 MB
#
#
# #Expanded:      476, #Frontier:   19.053, #Generated:   19.529, Time: 0,185 s, Memory: 114,84 MB
#
#
# #Expanded:      477, #Frontier:   19.073, #Generated:   19.550, Time: 0,186 s, Memory: 114,84 MB
#
#
# #Expanded:      478, #Frontier:   19.097, #Generated:   19.575, Time: 0,186 s, Memory: 114,84 MB
#
#
# #Expanded:      479, #Frontier:   19.137, #Generated:   19.616, Time: 0,186 s, Memory: 114,84 MB
#
#
# #Expanded:      480, #Frontier:   19.160, #Generated:   19.640, Time: 0,186 s, Memory: 114,84 MB
#
#
# #Expanded:      481, #Frontier:   19.223, #Generated:   19.704, Time: 0,187 s, Memory: 114,84 MB
#
#
# #Expanded:      482, #Frontier:   19.250, #Generated:   19.732, Time: 0,187 s, Memory: 114,84 MB
#
#
# #Expanded:      483, #Frontier:   19.273, #Generated:   19.756, Time: 0,187 s, Memory: 114,84 MB
#
#
# ...
# Solution length: 2074
# Number of states generated: 2442
# Elapsed time: 0.6282589435577393
# #Expanded:    2.288, #Frontier:   38.759, #Generated:   41.047, Time: 0,606 s, Memory: 126,38 MB
#
#
# #Expanded:    2.289, #Frontier:   38.761, #Generated:   41.050, Time: 0,606 s, Memory: 126,38 MB
#
#
# #Expanded:    2.290, #Frontier:   38.765, #Generated:   41.055, Time: 0,606 s, Memory: 126,38 MB
#
#
# #Expanded:    2.291, #Frontier:   38.764, #Generated:   41.055, Time: 0,606 s, Memory: 126,38 MB
#
#
# #Expanded:    2.292, #Frontier:   38.767, #Generated:   41.059, Time: 0,607 s, Memory: 126,38 MB
#
#
# #Expanded:    2.293, #Frontier:   38.772, #Generated:   41.065, Time: 0,607 s, Memory: 126,39 MB
#
#
# #Expanded:    2.294, #Frontier:   38.774, #Generated:   41.068, Time: 0,607 s, Memory: 126,39 MB
#
#
# #Expanded:    2.295, #Frontier:   38.780, #Generated:   41.075, Time: 0,607 s, Memory: 126,39 MB
#
#
# #Expanded:    2.296, #Frontier:   38.784, #Generated:   41.080, Time: 0,607 s, Memory: 126,39 MB
#
#
# #Expanded:    2.297, #Frontier:   38.783, #Generated:   41.080, Time: 0,607 s, Memory: 126,39 MB
#
#
# #Expanded:    2.298, #Frontier:   38.782, #Generated:   41.080, Time: 0,607 s, Memory: 126,39 MB
#
#
# #Expanded:    2.299, #Frontier:   38.782, #Generated:   41.081, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.300, #Frontier:   38.781, #Generated:   41.081, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.301, #Frontier:   38.780, #Generated:   41.081, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.302, #Frontier:   38.779, #Generated:   41.081, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.303, #Frontier:   38.778, #Generated:   41.081, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.304, #Frontier:   38.782, #Generated:   41.086, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.305, #Frontier:   38.789, #Generated:   41.094, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.306, #Frontier:   38.789, #Generated:   41.095, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.307, #Frontier:   38.789, #Generated:   41.096, Time: 0,608 s, Memory: 126,39 MB
#
#
# #Expanded:    2.308, #Frontier:   38.788, #Generated:   41.096, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.309, #Frontier:   38.789, #Generated:   41.098, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.310, #Frontier:   38.788, #Generated:   41.098, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.311, #Frontier:   38.787, #Generated:   41.098, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.312, #Frontier:   38.787, #Generated:   41.099, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.313, #Frontier:   38.787, #Generated:   41.100, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.314, #Frontier:   38.788, #Generated:   41.102, Time: 0,609 s, Memory: 126,39 MB
#
#
# #Expanded:    2.315, #Frontier:   38.794, #Generated:   41.109, Time: 0,609 s, Memory: 126,41 MB
#
#
# #Expanded:    2.316, #Frontier:   38.793, #Generated:   41.109, Time: 0,609 s, Memory: 126,41 MB
#
#
# #Expanded:    2.317, #Frontier:   38.792, #Generated:   41.109, Time: 0,609 s, Memory: 126,41 MB
#
#
# #Expanded:    2.318, #Frontier:   38.791, #Generated:   41.109, Time: 0,609 s, Memory: 126,41 MB
#
#
# #Expanded:    2.319, #Frontier:   38.790, #Generated:   41.109, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.320, #Frontier:   38.789, #Generated:   41.109, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.321, #Frontier:   38.788, #Generated:   41.109, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.322, #Frontier:   38.787, #Generated:   41.109, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.323, #Frontier:   38.791, #Generated:   41.114, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.324, #Frontier:   38.791, #Generated:   41.115, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.325, #Frontier:   38.790, #Generated:   41.115, Time: 0,610 s, Memory: 126,41 MB
#
#
# #Expanded:    2.326, #Frontier:   38.793, #Generated:   41.119, Time: 0,610 s, Memory: 126,42 MB
#
#
# #Expanded:    2.327, #Frontier:   38.795, #Generated:   41.122, Time: 0,610 s, Memory: 126,42 MB
#
#
# #Expanded:    2.328, #Frontier:   38.795, #Generated:   41.123, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.329, #Frontier:   38.794, #Generated:   41.123, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.330, #Frontier:   38.795, #Generated:   41.125, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.331, #Frontier:   38.794, #Generated:   41.125, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.332, #Frontier:   38.796, #Generated:   41.128, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.333, #Frontier:   38.797, #Generated:   41.130, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.334, #Frontier:   38.796, #Generated:   41.130, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.335, #Frontier:   38.796, #Generated:   41.131, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.336, #Frontier:   38.797, #Generated:   41.133, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.337, #Frontier:   38.798, #Generated:   41.135, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.338, #Frontier:   38.797, #Generated:   41.135, Time: 0,611 s, Memory: 126,42 MB
#
#
# #Expanded:    2.339, #Frontier:   38.797, #Generated:   41.136, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.340, #Frontier:   38.797, #Generated:   41.137, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.341, #Frontier:   38.798, #Generated:   41.139, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.342, #Frontier:   38.798, #Generated:   41.140, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.343, #Frontier:   38.797, #Generated:   41.140, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.344, #Frontier:   38.797, #Generated:   41.141, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.345, #Frontier:   38.799, #Generated:   41.144, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.346, #Frontier:   38.800, #Generated:   41.146, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.347, #Frontier:   38.802, #Generated:   41.149, Time: 0,612 s, Memory: 126,42 MB
#
#
# #Expanded:    2.348, #Frontier:   38.805, #Generated:   41.153, Time: 0,613 s, Memory: 126,44 MB
#
#
# #Expanded:    2.349, #Frontier:   38.807, #Generated:   41.156, Time: 0,613 s, Memory: 126,44 MB
#
#
# #Expanded:    2.350, #Frontier:   38.807, #Generated:   41.157, Time: 0,613 s, Memory: 126,44 MB
#
#
# #Expanded:    2.351, #Frontier:   38.806, #Generated:   41.157, Time: 0,613 s, Memory: 126,44 MB
#
#
# #Expanded:    2.352, #Frontier:   38.805, #Generated:   41.157, Time: 0,613 s, Memory: 126,44 MB
#
#
# #Expanded:    2.353, #Frontier:   38.804, #Generated:   41.157, Time: 0,613 s, Memory: 126,44 MB
#
#
# #Expanded:    2.354, #Frontier:   38.803, #Generated:   41.157, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.355, #Frontier:   38.802, #Generated:   41.157, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.356, #Frontier:   38.801, #Generated:   41.157, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.357, #Frontier:   38.800, #Generated:   41.157, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.358, #Frontier:   38.799, #Generated:   41.157, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.359, #Frontier:   38.798, #Generated:   41.157, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.360, #Frontier:   38.798, #Generated:   41.158, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.361, #Frontier:   38.798, #Generated:   41.159, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.362, #Frontier:   38.798, #Generated:   41.160, Time: 0,614 s, Memory: 126,44 MB
#
#
# #Expanded:    2.363, #Frontier:   38.797, #Generated:   41.160, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.364, #Frontier:   38.796, #Generated:   41.160, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.365, #Frontier:   38.795, #Generated:   41.160, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.366, #Frontier:   38.795, #Generated:   41.161, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.367, #Frontier:   38.794, #Generated:   41.161, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.368, #Frontier:   38.794, #Generated:   41.162, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.369, #Frontier:   38.793, #Generated:   41.162, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.370, #Frontier:   38.793, #Generated:   41.163, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.371, #Frontier:   38.793, #Generated:   41.164, Time: 0,615 s, Memory: 126,44 MB
#
#
# #Expanded:    2.372, #Frontier:   38.793, #Generated:   41.165, Time: 0,616 s, Memory: 126,44 MB
#
#
# #Expanded:    2.373, #Frontier:   38.792, #Generated:   41.165, Time: 0,616 s, Memory: 126,44 MB
#
#
# #Expanded:    2.374, #Frontier:   38.793, #Generated:   41.167, Time: 0,616 s, Memory: 126,44 MB
#
#
# #Expanded:    2.375, #Frontier:   38.795, #Generated:   41.170, Time: 0,616 s, Memory: 126,44 MB
#
#
# #Expanded:    2.376, #Frontier:   38.794, #Generated:   41.170, Time: 0,616 s, Memory: 126,44 MB
#
#
# #Expanded:    2.377, #Frontier:   38.793, #Generated:   41.170, Time: 0,617 s, Memory: 126,44 MB
#
#
# #Expanded:    2.378, #Frontier:   38.793, #Generated:   41.171, Time: 0,617 s, Memory: 126,44 MB
#
#
# #Expanded:    2.379, #Frontier:   38.792, #Generated:   41.171, Time: 0,617 s, Memory: 126,44 MB
#
#
# #Expanded:    2.380, #Frontier:   38.792, #Generated:   41.172, Time: 0,617 s, Memory: 126,44 MB
#
#
# #Expanded:    2.381, #Frontier:   38.791, #Generated:   41.172, Time: 0,617 s, Memory: 126,44 MB
#
#
# #Expanded:    2.382, #Frontier:   38.790, #Generated:   41.172, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.383, #Frontier:   38.789, #Generated:   41.172, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.384, #Frontier:   38.789, #Generated:   41.173, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.385, #Frontier:   38.789, #Generated:   41.174, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.386, #Frontier:   38.788, #Generated:   41.174, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.387, #Frontier:   38.787, #Generated:   41.174, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.388, #Frontier:   38.786, #Generated:   41.174, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.389, #Frontier:   38.785, #Generated:   41.174, Time: 0,618 s, Memory: 126,44 MB
#
#
# #Expanded:    2.390, #Frontier:   38.785, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.391, #Frontier:   38.784, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.392, #Frontier:   38.783, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.393, #Frontier:   38.782, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.394, #Frontier:   38.781, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.395, #Frontier:   38.780, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.396, #Frontier:   38.779, #Generated:   41.175, Time: 0,619 s, Memory: 126,44 MB
#
#
# #Expanded:    2.397, #Frontier:   38.783, #Generated:   41.180, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.398, #Frontier:   38.782, #Generated:   41.180, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.399, #Frontier:   38.782, #Generated:   41.181, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.400, #Frontier:   38.781, #Generated:   41.181, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.401, #Frontier:   38.780, #Generated:   41.181, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.402, #Frontier:   38.779, #Generated:   41.181, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.403, #Frontier:   38.778, #Generated:   41.181, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.404, #Frontier:   38.777, #Generated:   41.181, Time: 0,620 s, Memory: 126,44 MB
#
#
# #Expanded:    2.405, #Frontier:   38.777, #Generated:   41.182, Time: 0,621 s, Memory: 126,44 MB
#
#
# #Expanded:    2.406, #Frontier:   38.778, #Generated:   41.184, Time: 0,621 s, Memory: 126,45 MB
#
#
# #Expanded:    2.407, #Frontier:   38.778, #Generated:   41.185, Time: 0,621 s, Memory: 126,47 MB
#
#
# #Expanded:    2.408, #Frontier:   38.778, #Generated:   41.186, Time: 0,621 s, Memory: 126,47 MB
#
#
# #Expanded:    2.409, #Frontier:   38.779, #Generated:   41.188, Time: 0,622 s, Memory: 126,47 MB
#
#
# #Expanded:    2.410, #Frontier:   38.780, #Generated:   41.190, Time: 0,622 s, Memory: 126,47 MB
#
#
# #Expanded:    2.411, #Frontier:   38.780, #Generated:   41.191, Time: 0,622 s, Memory: 126,47 MB
#
#
# #Expanded:    2.412, #Frontier:   38.779, #Generated:   41.191, Time: 0,622 s, Memory: 126,47 MB
#
#
# #Expanded:    2.413, #Frontier:   38.780, #Generated:   41.193, Time: 0,623 s, Memory: 126,47 MB
#
#
# #Expanded:    2.414, #Frontier:   38.786, #Generated:   41.200, Time: 0,623 s, Memory: 126,47 MB
#
#
# #Expanded:    2.415, #Frontier:   38.786, #Generated:   41.201, Time: 0,623 s, Memory: 126,47 MB
#
#
# #Expanded:    2.416, #Frontier:   38.787, #Generated:   41.203, Time: 0,623 s, Memory: 126,47 MB
#
#
# #Expanded:    2.417, #Frontier:   38.786, #Generated:   41.203, Time: 0,624 s, Memory: 126,47 MB
#
#
# #Expanded:    2.418, #Frontier:   38.785, #Generated:   41.203, Time: 0,624 s, Memory: 126,47 MB
#
#
# #Expanded:    2.419, #Frontier:   38.786, #Generated:   41.205, Time: 0,624 s, Memory: 126,47 MB
#
#
# #Expanded:    2.420, #Frontier:   38.785, #Generated:   41.205, Time: 0,624 s, Memory: 126,47 MB
#
#
# #Expanded:    2.421, #Frontier:   38.788, #Generated:   41.209, Time: 0,624 s, Memory: 126,47 MB
#
#
# #Expanded:    2.422, #Frontier:   38.792, #Generated:   41.214, Time: 0,624 s, Memory: 126,47 MB
#
#
# #Expanded:    2.423, #Frontier:   38.793, #Generated:   41.216, Time: 0,625 s, Memory: 126,47 MB
#
#
# #Expanded:    2.424, #Frontier:   38.795, #Generated:   41.219, Time: 0,625 s, Memory: 126,47 MB
#
#
# #Expanded:    2.425, #Frontier:   38.800, #Generated:   41.225, Time: 0,625 s, Memory: 126,48 MB
#
#
# #Expanded:    2.426, #Frontier:   38.802, #Generated:   41.228, Time: 0,625 s, Memory: 126,48 MB
#
#
# #Expanded:    2.427, #Frontier:   38.804, #Generated:   41.231, Time: 0,625 s, Memory: 126,48 MB
#
#
# #Expanded:    2.428, #Frontier:   38.803, #Generated:   41.231, Time: 0,626 s, Memory: 126,48 MB
#
#
# #Expanded:    2.429, #Frontier:   38.804, #Generated:   41.233, Time: 0,626 s, Memory: 126,48 MB
#
#
# #Expanded:    2.430, #Frontier:   38.806, #Generated:   41.236, Time: 0,626 s, Memory: 126,48 MB
#
#
# #Expanded:    2.431, #Frontier:   38.805, #Generated:   41.236, Time: 0,626 s, Memory: 126,48 MB
#
#
# #Expanded:    2.432, #Frontier:   38.804, #Generated:   41.236, Time: 0,627 s, Memory: 126,48 MB
#
#
# #Expanded:    2.433, #Frontier:   38.803, #Generated:   41.236, Time: 0,627 s, Memory: 126,48 MB
#
#
# #Expanded:    2.434, #Frontier:   38.803, #Generated:   41.237, Time: 0,627 s, Memory: 126,48 MB
#
#
# #Expanded:    2.435, #Frontier:   38.802, #Generated:   41.237, Time: 0,627 s, Memory: 126,48 MB
#
#
# #Expanded:    2.436, #Frontier:   38.801, #Generated:   41.237, Time: 0,627 s, Memory: 126,48 MB
#
#
# #Expanded:    2.437, #Frontier:   38.802, #Generated:   41.239, Time: 0,628 s, Memory: 126,48 MB
#
#
# #Expanded:    2.438, #Frontier:   38.807, #Generated:   41.245, Time: 0,628 s, Memory: 126,48 MB
#
#
# #Expanded:    2.439, #Frontier:   38.807, #Generated:   41.246, Time: 0,628 s, Memory: 126,48 MB
#
#
# #Expanded:    2.440, #Frontier:   38.807, #Generated:   41.247, Time: 0,628 s, Memory: 126,48 MB
#
#
# #Expanded:    2.441, #Frontier:   38.806, #Generated:   41.247, Time: 0,628 s, Memory: 126,48 MB

# %%
render_plan(level_path, plan, strategy_name, heuristic, num_generated, elapsed_time, len(plan))
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Exiting...
